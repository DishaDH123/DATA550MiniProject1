# %% [markdown]
# ## Step 1. Describe your data set:
#
# * The data set was collected in the year 2016 by I-Cheng Yeh, Taiwan. The research was conducted with a purpose of obtaining predictive model from the perspective of risk management.
# * It contains information about the default credit card method chosen by customers in Taiwan for the year 2005 while the credit card issuers in Taiwan faced the cash and credit card debt crisis.
# * The data seems like the real credit card payment information of customers over a period of time. (Didnt like it)
# * The data collectors have used 6 data mining methods to predict the probability of default payment(response variable) based on various binary independent variables like Gender, Education, Amount of credit, Marital Status, Age, History of past payment, Amount of bill statements and Amount of previous payment.
# * In the end of the research, they have concluded that the Artificial neural network technique of data mining was most effective in giving the accurate results of finding the default payment method used by customers.

# %% [markdown]
# ## Step 2. Load the dataset

# %%
import pandas as pd
import altair as alt

# %%
creditdata=pd.read_csv("default of credit card clients.csv")

# %%
creditdata
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26     -1      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43     -1     -1
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1     -1
# 30000      30000      50000    1          2         1   46      0      0
#
#           X8     X9  ...        X15        X16        X17       X18       X19  \
# ...

# %% [markdown]
# ## Step 3. Explore your dataset

# %%
creditdata.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
# ...

# %% [markdown]
# * The data consists of 25 columns.
# * The column names are labeled from X1 to X23 and Y is the response.
# * The first row consists of the actual meaning of each column.
# * The index of column and row are not set to the read values.

# %%
creditdata.describe()
# Out:
#        Unnamed: 0     X1     X2     X3     X4     X5     X6     X7     X8  \
# count       30001  30001  30001  30001  30001  30001  30001  30001  30001
# unique      30001     82      3      8      5     57     12     12     12
# top            ID  50000      2      2      2     29      0      0      0
# freq            1   3365  18112  14030  15964   1605  14737  15730  15764
#
#            X9  ...    X15    X16    X17    X18    X19    X20    X21    X22  \
# count   30001  ...  30001  30001  30001  30001  30001  30001  30001  30001
# unique     12  ...  21549  21011  20605   7944   7900   7519   6938   6898
# top         0  ...      0      0      0      0      0      0      0      0
# freq    16455  ...   3195   3506   4020   5249   5396   5968   6408   6703
#
#           X23      Y
# count   30001  30001
# unique   6940      3
# top         0      0
# freq     7173  23364
#
# [4 rows x 25 columns]

# %% [markdown]
# * There are totally 30001 rows in the data.
# * Most common value in column X1 is 50000 which means that most of the customers were given a credit of 50000. There are 83 different credit limits given to the customers.
# * The most common in X2 , X3  and X4 columns is 2 implying that most of the customers are male with a university degree and are single and not married.
# * Most of the people are of the age 29 years(X5 column)
# * The columns X6:X11 all show the past payments and the data indicates that most of the customers use the revolving credit method to pay back. Which implies that most people delay their payment to the next month and pay an interest on the balance each month instead of paying the total balance.
# * The columns X12:X17 also have the most occurring value as 0 which implies that most customers have made no new purchase.
# * The columns X18:X25 also has the most occurring value as 0 indicating most users have no past payment history and have paid only 0 dollars towards their principle.
# * The response column has most occurring value as 0 indicating that most of the users did not use the default mode for payment of their credit card due.
# * There are 30001 unique IDs and all have a frequency 1 indicating that there are no duplicate values in the data and no NA's in the ID column.

# %%
creditdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30001 non-null  object
#  1   X1          30001 non-null  object
#  2   X2          30001 non-null  object
#  3   X3          30001 non-null  object
#  4   X4          30001 non-null  object
#  5   X5          30001 non-null  object
#  6   X6          30001 non-null  object
#  7   X7          30001 non-null  object
#  8   X8          30001 non-null  object
#  9   X9          30001 non-null  object
#  10  X10         30001 non-null  object
#  11  X11         30001 non-null  object
#  12  X12         30001 non-null  object
#  13  X13         30001 non-null  object
#  14  X14         30001 non-null  object
#  15  X15         30001 non-null  object
#  16  X16         30001 non-null  object
#  17  X17         30001 non-null  object
#  18  X18         30001 non-null  object
# ...

# %% [markdown]
# * This indicates all the columns are of the object type

# %%
creditdata.tail()
# Out:
#       Unnamed: 0      X1 X2 X3 X4  X5  X6  X7  X8  X9  ...    X15    X16  \
# 29996      29996  220000  1  3  1  39   0   0   0   0  ...  88004  31237
# 29997      29997  150000  1  3  2  43  -1  -1  -1  -1  ...   8979   5190
# 29998      29998   30000  1  2  2  37   4   3   2  -1  ...  20878  20582
# 29999      29999   80000  1  3  1  41   1  -1   0   0  ...  52774  11855
# 30000      30000   50000  1  2  1  46   0   0   0   0  ...  36535  32428
#
#          X17    X18    X19    X20   X21    X22   X23  Y
# 29996  15980   8500  20000   5003  3047   5000  1000  0
# 29997      0   1837   3526   8998   129      0     0  0
# 29998  19357      0      0  22000  4200   2000  3100  1
# 29999  48944  85900   3409   1178  1926  52964  1804  1
# 30000  15313   2078   1800   1430  1000   1000  1000  1
#
# [5 rows x 25 columns]

# %%
creditdata.dtypes
#All the columns are of the object type
# Out:
# Unnamed: 0    object
# X1            object
# X2            object
# X3            object
# X4            object
# X5            object
# X6            object
# X7            object
# X8            object
# X9            object
# X10           object
# X11           object
# X12           object
# X13           object
# X14           object
# X15           object
# X16           object
# X17           object
# X18           object
# X19           object
# X20           object
# X21           object
# X22           object
# X23           object
# Y             object
# dtype: object

# %% [markdown]
# ## Step 4. Initial thoughts

# %%
creditdata["X3"].unique()
creditdata["X4"].unique()
creditdata["X5"].unique()
creditdata["X6"].unique()
creditdata["X7"].unique()
creditdata["X8"].unique()
# Out:
# array(['PAY_0', '2', '-1', '0', '-2', '1', '3', '4', '8', '7', '5', '6'],
#       dtype=object)

# %% [markdown]
# * There are no 9 values in X6,X7,X8,X9,X10 indicating that there were no payment delays for 9 months or above in September 2005

# %%
creditdata["X10"].unique()
creditdata["X11"].unique()
creditdata["X12"].unique()
# Out:
# array(['BILL_AMT1', '3913', '2682', ..., '1683', '-1645', '47929'],
#       dtype=object)

# %% [markdown]
# * In X10 and X11, there are no 1s indicating there were no delay in payments of 1 month in May 2005
# * In X12 wd have negative value for bill amount which means that the user has given extra amount and the credit is hence negative. (This can be an outlier)
# * As an initial thought we can conclude that most of the customers don't pay their credit card bill by the default payment method and are usually postponing the bill to the next month and not paying any principle amount.

# %% [markdown]
# ## Step 5. Data Wrangling

# %% [markdown]
# Here we will first read the dataset and set the index column to be the first row of the data. This will directly label the columns as their column headers instead of Xs

# %%
creditdata=pd.read_csv("default of credit card clients.csv", header=[1])

# %%
creditdata.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
creditdata.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# From the above we get more information on the data as each column is now an integer and not of the object type. So we get various other results like mean, standard deviation etc.

# %%
creditdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
alt.data_transformers.enable('default', max_rows=None)
alt.Chart(creditdata.melt()).mark_boxplot().encode(
    x='variable',
    y='value'
)

# %%
#bill amt and pay_amt outlier at a single row.
creditdata.query('BILL_AMT3 >= 1600000')
creditdata=creditdata.drop(5296)

# %%
creditdata['MARRIAGE']=creditdata['MARRIAGE'].astype('category')
creditdata['EDUCATION']=creditdata['EDUCATION'].astype('category')
creditdata['SEX']=creditdata['SEX'].astype('category')

# %%
creditdata.info()

# %% [markdown]
# ## Step 6. Reasearch Question

# %% [markdown]
# 1. Descriptive
# * Based on gender, which method of payment is used by most of the population?
#
# 2. Explanatory
# * What is the maximum limit issued by the credit card companies to its customers based on their age. Do the older people get a bigger credit limit or the younger people get a bigger credit limit?
# * Payment Delay Status for first-three quarters. How much does the credit granter needs to prepare for the cash flow towards the final fourth quarter of the year.
# * Identify defaulter within age group. Determine How much is the risk association of approving the credit of any new applicant considering the age bracket?

# %% [markdown]
# ## Step 7. Data Analysis and Visualizations

# %%
import altair as alt
import pandas as pd
import numpy as np
alt.renderers.enable('mimetype')
alt.data_transformers.enable('data_server')
# Out:
# DataTransformerRegistry.enable('data_server')

# %%
alt.Chart(creditdata).mark_bar().encode(x='AGE',
    y='LIMIT_BAL',
    color='AGE',
)
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ##### Objective: Payment Delay Status for first-three quarters

# %%
creditdata_subset=creditdata.query('PAY_0 >= 1')
creditdata_subset['PAY_0']=creditdata_subset['PAY_0'].astype('category')
select = alt.selection(type='interval')
values = alt.Chart(creditdata_subset).mark_point().encode(alt.X('BILL_AMT1',axis=alt.Axis(title='Bill amount (in NT dollar)', grid=False,labelFontSize=15,titleFontSize=17)),alt.Y('PAY_AMT1',axis=alt.Axis(title='Paid amount (in NT dollar)', grid=False,labelFontSize=15,titleFontSize=17)),
            opacity=alt.value(0.3),
    color=alt.condition(select, 'PAY_0:N', alt.value('lightgray'))
).properties(title="Last Quarter monthly delayed report").add_selection(
    select
)
bars = alt.Chart(creditdata_subset).mark_bar().encode(
     alt.X('count(PAY_0):Q', axis=alt.Axis(title='Total records', grid=False,labelFontSize=13,titleFontSize=15)),
    alt.Y('PAY_0:N',axis=alt.Axis(title='Count of month payment delayed', grid=False,labelFontSize=13,titleFontSize=15)),
    color=alt.Color('PAY_0:N',legend=alt.Legend(
        orient="bottom",title="Month count payment delayed",labelFontSize=8,titleFontSize=10))
).properties(title="Summary of range",height=200).transform_filter(
    select
)
values & bars

# %% [markdown]
# ##### Objective : Identify defaulter within age group

# %%
age_defaulters=creditdata[['AGE','default payment next month']]
age_defaulters['default payment next month']=pd.to_numeric(age_defaulters['default payment next month'])
age_defaulters['AGE'] = pd.cut(age_defaulters['AGE'],bins=[20,40,60,100])
age_defaulters_percentage=age_defaulters.groupby(['AGE']).sum()
age_defaulters_percentage['total']=age_defaulters.groupby(['AGE']).count()
age_defaulters_percentage['PERCENTAGE']=(age_defaulters_percentage['default payment next month']/age_defaulters_percentage['total'])*100
age_defaulters_percentage['PERCENTAGE']=round(age_defaulters_percentage['PERCENTAGE'],2)
age_defaulters_percentage=age_defaulters_percentage.reset_index()
age_defaulters_percentage['AGE']=age_defaulters_percentage['AGE'].astype(str)
bars=alt.Chart(age_defaulters_percentage).mark_bar().encode(x=alt.X('PERCENTAGE:Q', axis=alt.Axis(title='Percentage of defaulters(in %)', grid=False)),y=alt.Y('AGE:N', sort='x', axis=alt.Axis(title='Age Group')))
text= bars.mark_text(align = "left", baseline = "middle",dx=2).encode(text = "PERCENTAGE:Q")

chart =(bars + text).properties(height = 240,title="Age group vs default")

chart.configure_axis(grid=False).configure_view(strokeWidth=0).configure_title(fontSize=20,font='Courier',anchor='start',color='grey').configure_axis(labelFontSize=13,titleFontSize=15)
